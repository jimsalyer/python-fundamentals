# %% [markdown]
# ### Solutions

# %% [markdown]
# #### Question 1

# %% [markdown]
# Write a function that takes a variable number of arguments (with a minimum of one), and returns the average of these numbers.

# %%
def average(value, *values):
    all_values = (value, *values)
    return sum(all_values) / len(all_values)

print("3 args:", average(1, 2, 3))
print("2 args:", average(1, 2))
print("1 arg:", average(1))
# Out:
# 3 args: 2.0
# 2 args: 1.5
# 1 arg: 1.0

# %% [markdown]
# #### Question 2

# %% [markdown]
# Write a function that returns a string based on two input arguments:
# - a character or string to be repeated
# - the number of times the string should be repeated

# %% [markdown]
# The function should be such that the number of repetitions defaults to `10` if it is not passed by the caller, and the default character to be repeated should be a negative sign (`-`).
#
# Call your function `separator`.
#
# Use a keyword-only argument for the string argument.

# %%
def separator(repetitions=10, *, value="-"):
    return value * repetitions

print("separator() with both repetitions and value:", separator(5, value="="))
print("separator() with just repetitions:", separator(3))
print("separator() with no arguments:", separator())
# Out:
# separator() with both repetitions and value: =====
# separator() with just repetitions: ---
# separator() with no arguments: ----------

# %% [markdown]
# #### Question 3

# %% [markdown]
# Write a lambda function that returns the number of unique elements in an iterable. This could be the number of unique characters in a string, or the number of unique elements in a list, tuple, etc.
#
# If the iterable received by the lambda function is empty, then it should return `0`.

# %%
unique_count = lambda iterable: len(set(iterable))
print(unique_count("string"))
print(unique_count([1, 2, 3, 4, 5, 1]))
print(unique_count((1, 2, 2, 3, 4, 5, 6, 7)))
print(unique_count([]))
print(unique_count(""))
print(unique_count(()))
print(unique_count(set()))
# Out:
# 6
# 5
# 7
# 0
# 0
# 0
# 0

# %% [markdown]
# #### Question 4

# %% [markdown]
# Write a function that receives a string as an argument (defaults to an empty string) and returns a dictionary with the unique words and their frequency.

# %% [markdown]
# For example, for a string such as:
#
# ```
# This is the first sentence. This is the scecond sentence. This is not the fourth sentence, it is the third sentence.
# ```
#
# the result of the function should be:

# %%
result = {
    'This': 3,
    'is': 4,
    'the': 4,
    'first': 1,
    'sentence': 4,
    'scecond': 1,
    'not': 1,
    'fourth': 1,
    'it': 1,
    'third': 1
}

# %% [markdown]
# You may assume that word separators are limited to spaces, commas, and periods (no newline characters).

# %% [markdown]
# Hint: You will want to split based on some character. Problem is that we really need to split based on three different characters: spaces, commas and periods. One approach would be to replace all commas and periods with spaces and then split on spaces.

# %%
from collections import Counter

def word_frequencies(value=""):
    value = value.strip()
    value = value.replace(",", " ")
    value = value.replace(".", " ")
    words = [word for word in value.split(" ") if len(word.strip()) != 0]
    freqs = Counter(words)
    return dict(freqs)

example_1 = "This is the first sentence. This is the scecond sentence. This is not the fourth sentence, it is the third sentence."
example_2 = "                       ....,,,,     , . , . "

print(f"Word frequencies for \"{example_1}\": {word_frequencies(example_1)}")
print(f"Word frequencies for default value: {word_frequencies()}")
print(f"Word frequencies for \"{example_2}\": {word_frequencies(example_2)}")
# Out:
# Word frequencies for "This is the first sentence. This is the scecond sentence. This is not the fourth sentence, it is the third sentence.": {'This': 3, 'is': 4, 'the': 4, 'first': 1, 'sentence': 4, 'scecond': 1, 'not': 1, 'fourth': 1, 'it': 1, 'third': 1}
# Word frequencies for default value: {}
# Word frequencies for "                       ....,,,,     , . , . ": {}
